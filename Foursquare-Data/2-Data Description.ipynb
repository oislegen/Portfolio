# %% [markdown]
# # Where Should a Data-Science Job Candidate  Move in the Bay Area?
#
# ## 1. Problem Description:
#
# There are currently many data science jobs in the Bay Area, which attract many job seekers in this field to the region. However, some of these job seekers first move to the area for traning purposes and they want to decide on a long-term rental place before they know the location of their future job. How can such a person decide which city to move considering the abundance of data science job openings in that city and other criteria affecting their quality of life?
#
# Suppose that your friend, who is looking for a full-time data science job near San Francisco, Bay Area, approaches you with the following problem: She needs to move to the Bay Area before finding a job because she plans to attend a 7-week long data science camp in Silicon Valley before applying for jobs. The long-term rentals are cheaper and she does not want to move again within the Bay Area shortly after finding a job. Therefore, she wants to move to a city which has a high chance of being close to her future job and provides a good quality of life in general. Her criteria for the ideal city to live in are:
#
# 1- The city should include companies with job openings for data scientists. The more job openings, the better.
#
# 2- The city ideally should have a low crime rate.
#
# 3- Given that she is Turkish, she would like the Turkish restaurants nearby to have a high average rating.
#
# She wants you to create a ranking of the cities best-suited to her criteria above.

# %% [markdown]
# ## 2. Data Description and Cleaning:
#
# We will describe and clean the data, needed to rank the cities according to three criteria above:
#
# ### 2.1. Job Openings for Data Scientists near San Francisco, Bay Area:
#
# [Indeed.com](https://www.indeed.com) provides full-time job openings for data scientists within 50 mile radius of San Francisco Bay Area, CA. We can use the url for this search, to parse the number of jobs in each city from the web page.

# %% [markdown]
# First, we import the libraries necessary for the analysis.

# %%
import requests # library for making HTTP requests in Python
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analysis
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

from bs4 import BeautifulSoup # library for pulling data out of HTML and XML files

# %% [markdown]
# We can use the url below to parse through Beautiful Soup the html data on [Indeed.com](https://www.indeed.com) looking for full-time job openings with the key word "data scientist" within 50 mile radius of San Francisco Bay Area, CA.

# %%
url='https://www.indeed.com/jobs?q=data+scientist&jt=fulltime&l=San+Francisco+Bay+Area%2C+CA&radius=50'
index = requests.get(url).text #Request the text data from Indeed.com
soup = BeautifulSoup(index, 'html.parser')

# %% [markdown]
# We then scrape the data on the side bar of the web page which includes the number of data science jobs in cities within 50 miles from San Francisco Bay Area. Finally, we put the data into a dataframe and split the city and the number of data science job openings into two columns.

# %%
city_job = soup.find_all(id="LOCATION_rbo")

df=[cj.get_text(strip=True) for cj in city_job]

df=pd.DataFrame(df)

df=df[0].str.split(")", expand=True).T 
df=df[0].str.split("(", expand=True)
df[0]=df[0].str.split(",", expand=True)
df.columns=['City','Job Openings']
df
# Out:
#                                    City Job Openings
# 0                         San Francisco         1439
# 1                             Sunnyvale          529
# 2                              San Jose          258
# 3                             Palo Alto          247
# 4                            Menlo Park          241
# 5                   South San Francisco          240
# 6                           Santa Clara          201
# 7                         Mountain View          200
# 8                          Redwood City          186
# 9                    Santa Clara Valley          168
# 10                            Livermore          115
# 11                             Berkeley           77
# 12                            San Mateo           75
# 13               San Francisco Bay Area           72
# 14                              Oakland           69
# 15  Data Scientist jobsnationwidemore »         None

# %% [markdown]
# We drop the last row which contains a None value. The location "San Francisco Bay Area" is not specific enough to assign the jobs to a city in the Bay Area, and Santa Clara Valley area contains 18 cities and towns so the jobs there cannot be assigned to specific cities either. Therefore, we drop these two rows as well. Finally, we convert the first column into a string and second column into numeric values.

# %%
df.dropna(inplace=True) #Drop the last column with a None value. 
df=df[~df.City.str.contains('San Francisco Bay Area|Santa Clara Valley')].reset_index(drop=True) #Drop rows which contain 'San Francisco Bay Area or 'Santa Clara Valley' in one of their cells.

df['City']=df['City'].astype(str) #Convert the first column into string
df['Job Openings']=df['Job Openings'].apply(pd.to_numeric) #Convert the second column in the dataframe to numeric values
df.dtypes
# Out:
# City            object
# Job Openings     int64
# dtype: object

# %% [markdown]
# ### 2.2. Crime data in the cities with data scientist jobs:
#
# We can extract the violent and property crime rates per 1000 people for each city listed above. The crime rate data in all cities in California is available on the following Wikipedia page:

# %%
url='https://en.wikipedia.org/wiki/California_locations_by_crime_rate#Cities_and_other_agencies'

index = requests.get(url).text #Request the text data from the Wikipedia page
soup2 = BeautifulSoup(index, 'html.parser')

# %% [markdown]
# We extract the table from the html file above which contains the violent and property crime rate data in all cities in California and put it into a dataframe:

# %%
mtable=soup2.find_all('table') #Find all tables in the document

#Extract all text in the table except the column names
df_crime=[
    [td.get_text(strip=True) for td in tr.find_all('td') if td.string or td.a]
    for tr in mtable[2].find_all('tr')[1:]
]

#Extract all column names in the table
Header=[]
for st in mtable[2].find_all('th'):
    st1=st.next_element.strip()
    if st.br:
        st2=st.find_next('br').next_element.strip()
    else: 
        st2=""
    Header.append(" ".join([st1, st2]))

#Create a dataframe which contains all the necessary data in the table
df_crime=pd.DataFrame(df_crime,columns=Header)

df_crime
# Out:
#                         City/Agency           County  Population   \
# 0                           Adelanto   San Bernardino      31,213
# 1                       Agoura Hills      Los Angeles      20,767
# 2                            Alameda          Alameda      77,048
# 3                             Albany          Alameda      19,350
# 4                           Alhambra      Los Angeles      84,931
# 5                        Aliso Viejo           Orange      50,671
# 6                            Alturas            Modoc       2,615
# 7                    American Canyon             Napa      20,379
# 8                            Anaheim           Orange     346,956
# 9                           Anderson           Shasta      10,176
# 10                            Angels        Calaveras       3,716
# 11                           Antioch     Contra Costa     108,223
# 12                      Apple Valley   San Bernardino      71,329
# 13                           Arcadia      Los Angeles      57,950
# 14                            Arcata         Humboldt      17,748
# 15                     Arroyo Grande  San Luis Obispo      17,829
# 16                           Artesia      Los Angeles      16,788
# 17                             Arvin             Kern      20,541
# 18                        Atascadero  San Luis Obispo      29,268
# 19                          Atherton        San Mateo       7,221
# 20                           Atwater           Merced      28,961
# 21                            Auburn           Placer      14,042
# 22                            Avalon      Los Angeles       3,784
# 23                            Avenal            Kings      13,914
# 24                             Azusa      Los Angeles      48,224
# 25                       Bakersfield             Kern     367,406
# 26                      Baldwin Park      Los Angeles      76,933
# 27                           Banning        Riverside      30,699
# 28                           Barstow   San Bernardino      23,349
# 29                          Beaumont        Riverside      41,323
# 30                              Bell      Los Angeles      36,059
# 31                        Bellflower      Los Angeles      77,830
# 32                      Bell Gardens      Los Angeles      43,089
# 33                           Belmont        San Mateo      26,947
# 34                         Belvedere            Marin       2,135
# 35                           Benicia           Solano      27,766
# 36                          Berkeley          Alameda     117,753
# 37                     Beverly Hills      Los Angeles      34,788
# 38                     Big Bear Lake   San Bernardino       5,148
# 39                             Biggs            Butte       1,701
# 40                            Bishop             Inyo       3,860
# 41                            Blythe        Riverside      19,669
# 42                          Bradbury      Los Angeles       1,084
# 43                           Brawley         Imperial      25,695
# 44                              Brea           Orange      41,359
# 45                         Brentwood     Contra Costa      55,826
# 46                          Brisbane        San Mateo       4,482
# 47                         Broadmoor        San Mateo       4,343
# 48                          Buellton    Santa Barbara       4,997
# 49                        Buena Park           Orange      83,414
# 50                           Burbank      Los Angeles     105,041
# 51                        Burlingame        San Mateo      30,161
# 52                         Calabasas      Los Angeles      24,325
# 53                          Calexico         Imperial      39,572
# 54                   California City             Kern      13,168
# 55                          Calimesa        Riverside       8,238
# 56                         Calistoga             Napa       5,277
# 57                         Camarillo          Ventura      66,272
# 58                          Campbell      Santa Clara      40,872
# 59                       Canyon Lake        Riverside      10,987
# 60                          Capitola       Santa Cruz      10,134
# 61                          Carlsbad        San Diego     112,297
# 62                 Carmel-by-the-Sea         Monterey       3,871
# 63                       Carpinteria    Santa Barbara      13,654
# 64                            Carson      Los Angeles      92,838
# 65                    Cathedral City        Riverside      53,368
# 66                             Ceres       Stanislaus      46,903
# 67                          Cerritos      Los Angeles      49,867
# 68                             Chico            Butte      88,562
# 69                             Chino   San Bernardino      81,600
# 70                       Chino Hills   San Bernardino      76,972
# 71                        Chowchilla           Madera      17,079
# 72                       Chula Vista        San Diego     259,894
# 73                    Citrus Heights       Sacramento      85,758
# 74                         Claremont      Los Angeles      36,042
# 75                           Clayton     Contra Costa      11,646
# 76                         Clearlake             Lake      14,914
# 77                        Cloverdale           Sonoma       8,766
# 78                            Clovis           Fresno     100,705
# 79                         Coachella        Riverside      43,633
# 80                          Coalinga           Fresno      16,445
# 81                             Colma        San Mateo       1,503
# 82                            Colton   San Bernardino      53,485
# 83                            Colusa           Colusa       5,942
# 84                          Commerce      Los Angeles      13,033
# 85                           Compton      Los Angeles      98,224
# 86                           Concord     Contra Costa     126,744
# 87                          Corcoran            Kings      23,057
# 88                           Corning           Tehama       7,569
# 89                            Corona        Riverside     161,128
# 90                          Coronado        San Diego      23,385
# 91                        Costa Mesa           Orange     112,709
# 92                            Cotati           Sonoma       7,424
# 93                            Covina      Los Angeles      48,681
# 94                     Crescent City        Del Norte       7,090
# 95                            Cudahy      Los Angeles      24,175
# 96                       Culver City      Los Angeles      39,561
# 97                         Cupertino      Santa Clara      60,564
# 98                           Cypress           Orange      49,370
# 99                         Daly City        San Mateo     105,628
# 100                       Dana Point           Orange      34,244
# 101                         Danville     Contra Costa      43,685
# 102                            Davis             Yolo      66,360
# 103                           Delano             Kern      52,224
# 104                          Del Mar        San Diego       4,305
# 105                     Del Rey Oaks         Monterey       1,683
# 106               Desert Hot Springs        Riverside      28,086
# 107                      Diamond Bar      Los Angeles      56,665
# 108                           Dinuba           Tulare      23,815
# 109                            Dixon           Solano      19,103
# 110                           Dorris         Siskiyou         899
# 111                        Dos Palos           Merced       5,081
# 112                           Downey      Los Angeles     113,595
# 113                           Duarte      Los Angeles      21,817
# 114                           Dublin          Alameda      53,795
# 115                         Dunsmuir         Siskiyou       1,569
# 116                   East Palo Alto        San Mateo      29,377
# 117                         Eastvale        Riverside      55,504
# 118                         El Cajon        San Diego     102,838
# 119                        El Centro         Imperial      43,532
# 120                       El Cerrito     Contra Costa      24,485
# 121                        Elk Grove       Sacramento     162,957
# 122                         El Monte      Los Angeles     116,220
# 123  El Paso de Robles (Paso Robles)  San Luis Obispo      31,117
# 124                       El Segundo      Los Angeles      16,990
# 125                       Emeryville          Alameda      10,972
# 126                        Encinitas        San Diego      62,071
# 127                          Escalon      San Joaquin       7,281
# 128                        Escondido        San Diego     149,839
# 129                             Etna         Siskiyou         715
# 130                           Eureka         Humboldt      26,843
# 131                           Exeter           Tulare      10,524
# 132                          Fairfax            Marin       7,647
# 133                        Fairfield           Solano     110,300
# 134                     Farmersville           Tulare      10,752
# 135                         Ferndale         Humboldt       1,360
# 136                         Fillmore          Ventura      15,311
# 137                        Firebaugh           Fresno       8,238
# 138                           Folsom       Sacramento      73,329
# 139                          Fontana   San Bernardino     204,532
# 140                       Fort Bragg        Mendocino       7,245
# 141                       Fort Jones         Siskiyou         681
# 142                          Fortuna         Humboldt      11,752
# 143                      Foster City        San Mateo      32,836
# 144                  Fountain Valley           Orange      57,024
# 145                           Fowler           Fresno       6,032
# 146                          Fremont          Alameda     227,575
# 147                           Fresno           Fresno     513,187
# 148                        Fullerton           Orange     139,895
# 149                             Galt       Sacramento      24,671
# 150                          Gardena      Los Angeles      60,233
# 151                     Garden Grove           Orange     176,106
# 152                           Gilroy      Santa Clara      52,415
# 153                         Glendale      Los Angeles     197,079
# 154                         Glendora      Los Angeles      51,292
# 155                           Goleta    Santa Barbara      30,669
# 156                         Gonzales         Monterey       8,459
# 157                    Grand Terrace   San Bernardino      12,405
# 158                     Grass Valley           Nevada      12,777
# 159                       Greenfield         Monterey      16,986
# 160                          Gridley            Butte       6,558
# 161                     Grover Beach  San Luis Obispo      13,497
# 162                        Guadalupe    Santa Barbara       7,260
# 163                          Gustine           Merced       5,667
# 164                          Hanford            Kings      54,824
# 165                 Hawaiian Gardens      Los Angeles      14,490
# 166                        Hawthorne      Los Angeles      86,670
# 167                          Hayward          Alameda     153,319
# 168                       Healdsburg           Sonoma      11,569
# 169                            Hemet        Riverside      82,412
# 170                         Hercules     Contra Costa      25,026
# 171                    Hermosa Beach      Los Angeles      19,873
# 172                         Hesperia   San Bernardino      92,592
# 173                     Hidden Hills      Los Angeles       1,915
# 174                         Highland   San Bernardino      54,559
# 175                     Hillsborough        San Mateo      11,382
# 176                        Hollister       San Benito      36,967
# 177                        Holtville         Imperial       6,030
# 178                          Hughson       Stanislaus       7,089
# 179                 Huntington Beach           Orange     199,152
# 180                  Huntington Park      Los Angeles      59,064
# 181                            Huron           Fresno       6,792
# 182                         Imperial         Imperial      16,535
# 183                   Imperial Beach        San Diego      27,234
# 184                     Indian Wells        Riverside       5,211
# 185                            Indio        Riverside      84,540
# 186                         Industry      Los Angeles         205
# 187                        Inglewood      Los Angeles     111,997
# 188                             Ione           Amador       6,773
# 189                           Irvine           Orange     242,971
# 190                        Irwindale      Los Angeles       1,426
# 191                          Isleton       Sacramento         825
# 192                          Jackson           Amador       4,534
# 193                    Jurupa Valley        Riverside      98,684
# 194                       Kensington     Contra Costa       5,281
# 195                           Kerman           Fresno      14,538
# 196                        King City         Monterey      13,336
# 197                        Kingsburg           Fresno      11,762
# 198             La Cañada Flintridge      Los Angeles      20,627
# 199                        Lafayette     Contra Costa      25,355
# 200                     Laguna Beach           Orange      23,371
# 201                     Laguna Hills           Orange      31,035
# 202                    Laguna Niguel           Orange      65,033
# 203                     Laguna Woods           Orange      16,480
# 204                         La Habra           Orange      61,964
# 205                 La Habra Heights      Los Angeles       5,451
# 206                    Lake Elsinore        Riverside      58,665
# 207                      Lake Forest           Orange      79,748
# 208                         Lakeport             Lake       4,763
# 209                         Lakewood      Los Angeles      81,382
# 210                          La Mesa        San Diego      59,005
# 211                        La Mirada      Los Angeles      49,277
# 212                        Lancaster      Los Angeles     160,190
# 213                         La Palma           Orange      15,977
# 214                        La Puente      Los Angeles      40,583
# 215                        La Quinta        Riverside      39,753
# 216                         La Verne      Los Angeles      32,067
# 217                         Lawndale      Los Angeles      33,340
# 218                      Lemon Grove        San Diego      26,332
# 219                          Lemoore            Kings      25,080
# 220                          Lincoln           Placer      45,792
# 221                          Lindsay           Tulare      13,300
# 222                        Livermore          Alameda      86,147
# 223                       Livingston           Merced      13,690
# 224                             Lodi      San Joaquin      63,601
# 225                       Loma Linda   San Bernardino      23,798
# 226                           Lomita      Los Angeles      20,677
# 227                           Lompoc    Santa Barbara      43,809
# 228                       Long Beach      Los Angeles     471,123
# 229                     Los Alamitos           Orange      11,708
# 230                        Los Altos      Santa Clara      30,256
# 231                  Los Altos Hills      Santa Clara       8,408
# 232                      Los Angeles      Los Angeles   3,906,772
# 233                        Los Banos           Merced      37,011
# 234                        Los Gatos      Santa Clara      30,614
# 235                          Lynwood      Los Angeles      71,812
# 236                        McFarland             Kern      12,346
# 237                           Madera           Madera      63,495
# 238                           Malibu      Los Angeles      12,912
# 239                    Mammoth Lakes             Mono       8,033
# 240                  Manhattan Beach      Los Angeles      35,872
# 241                          Manteca      San Joaquin      73,055
# 242                           Marina         Monterey      20,530
# 243                         Martinez     Contra Costa      37,416
# 244                       Marysville             Yuba      12,242
# 245                          Maywood      Los Angeles      27,833
# 246                          Mendota           Fresno      11,480
# 247                          Menifee        Riverside      84,843
# 248                       Menlo Park        San Mateo      33,321
# 249                           Merced           Merced      81,603
# 250                      Mill Valley            Marin      14,411
# 251                         Milpitas      Santa Clara      70,568
# 252                    Mission Viejo           Orange      97,124
# 253                          Modesto       Stanislaus     205,820
# 254                         Monrovia      Los Angeles      37,225
# 255                         Montague         Siskiyou       1,398
# 256                        Montclair   San Bernardino      38,347
# 257                       Montebello      Los Angeles      63,737
# 258                         Monterey         Monterey      28,512
# 259                    Monterey Park      Los Angeles      61,284
# 260                     Monte Sereno      Santa Clara       3,511
# 261                         Moorpark          Ventura      35,299
# 262                           Moraga     Contra Costa      16,953
# 263                    Moreno Valley        Riverside     202,911
# 264                      Morgan Hill      Santa Clara      41,585
# 265                        Morro Bay  San Luis Obispo      10,516
# 266                    Mountain View      Santa Clara      78,759
# 267                     Mount Shasta         Siskiyou       3,267
# 268                         Murrieta        Riverside     108,376
# 269                             Napa             Napa      79,572
# 270                    National City        San Diego      60,130
# 271                          Needles   San Bernardino       4,944
# 272                      Nevada City           Nevada       3,055
# 273                           Newark          Alameda      44,467
# 274                           Newman       Stanislaus      10,742
# 275                    Newport Beach           Orange      87,759
# 276                            Norco        Riverside      26,933
# 277                          Norwalk      Los Angeles     106,838
# 278                           Novato            Marin      54,756
# 279                          Oakdale       Stanislaus      21,651
# 280                          Oakland          Alameda     409,994
# 281                           Oakley     Contra Costa      38,851
# 282                        Oceanside        San Diego     174,102
# 283                             Ojai          Ventura       7,607
# 284                          Ontario   San Bernardino     168,278
# 285                           Orange           Orange     140,767
# 286                      Orange Cove           Fresno       9,704
# 287                           Orinda     Contra Costa      18,904
# 288                           Orland            Glenn       7,511
# 289                         Oroville            Butte      16,090
# 290                           Oxnard          Ventura     204,159
# 291                         Pacifica        San Mateo      38,925
# 292                    Pacific Grove         Monterey      15,612
# 293                         Palmdale      Los Angeles     158,210
# 294                      Palm Desert        Riverside      50,971
# 295                     Palm Springs        Riverside      46,665
# 296                        Palo Alto      Santa Clara      67,169
# 297             Palos Verdes Estates      Los Angeles      13,668
# 298                         Paradise            Butte      26,306
# 299                        Paramount      Los Angeles      55,194
# 300                          Parlier           Fresno      14,948
# 301                         Pasadena      Los Angeles     140,373
# 302                        Patterson       Stanislaus      20,977
# 303                           Perris        Riverside      73,223
# 304                         Petaluma           Sonoma      59,803
# 305                      Pico Rivera      Los Angeles      63,970
# 306                         Piedmont          Alameda      11,170
# 307                           Pinole     Contra Costa      19,034
# 308                      Pismo Beach  San Luis Obispo       7,910
# 309                        Pittsburg     Contra Costa      67,509
# 310                        Placentia           Orange      52,513
# 311                      Placerville        El Dorado      10,486
# 312                    Pleasant Hill     Contra Costa      34,363
# 313                       Pleasanton          Alameda      75,060
# 314                           Pomona      Los Angeles     151,899
# 315                      Porterville           Tulare      55,391
# 316                     Port Hueneme          Ventura      22,247
# 317                            Poway        San Diego      49,786
# 318                   Rancho Cordova       Sacramento      68,636
# 319                 Rancho Cucamonga   San Bernardino     172,694
# 320                    Rancho Mirage        Riverside      17,926
# 321              Rancho Palos Verdes      Los Angeles      42,645
# 322           Rancho Santa Margarita           Orange      49,558
# 323                        Red Bluff           Tehama      14,103
# 324                          Redding           Shasta      91,426
# 325                         Redlands   San Bernardino      70,295
# 326                    Redondo Beach      Los Angeles      68,075
# 327                     Redwood City        San Mateo      81,870
# 328                          Reedley           Fresno      25,186
# 329                           Rialto   San Bernardino     102,540
# 330                         Richmond     Contra Costa     108,464
# 331                       Ridgecrest             Kern      28,830
# 332                         Rio Dell         Humboldt       3,358
# 333                        Rio Vista           Solano       7,825
# 334                            Ripon      San Joaquin      14,859
# 335                        Riverbank       Stanislaus      23,690
# 336                        Riverside        Riverside     319,453
# 337                          Rocklin           Placer      60,371
# 338                     Rohnert Park           Sonoma      41,535
# 339                    Rolling Hills      Los Angeles       1,896
# 340            Rolling Hills Estates      Los Angeles       8,233
# 341                         Rosemead      Los Angeles      54,748
# 342                        Roseville           Placer     128,997
# 343                             Ross            Marin       2,476
# 344                       Sacramento       Sacramento     482,767
# 345                       St. Helena             Napa       5,978
# 346                          Salinas         Monterey     156,908
# 347                   San Bernardino   San Bernardino     214,588
# 348                        San Bruno        San Mateo      42,787
# 349       San Buenaventura (Ventura)          Ventura     109,246
# 350                     San Clemente           Orange      65,397
# 351                        Sand City         Monterey         343
# 352                        San Diego        San Diego   1,368,690
# 353                        San Dimas      Los Angeles      33,953
# 354                     San Fernando      Los Angeles      24,362
# 355                    San Francisco    San Francisco     850,294
# 356                      San Gabriel      Los Angeles      40,409
# 357                           Sanger           Fresno      24,771
# 358                      San Jacinto        Riverside      46,216
# 359                         San Jose      Santa Clara   1,009,679
# 360              San Juan Capistrano           Orange      36,124
# 361                      San Leandro          Alameda      88,690
# 362                  San Luis Obispo  San Luis Obispo      46,672
# 363                       San Marcos        San Diego      90,799
# 364                       San Marino      Los Angeles      13,371
# 365                        San Mateo        San Mateo     102,082
# 366                        San Pablo     Contra Costa      29,831
# 367                       San Rafael            Marin      59,292
# 368                        San Ramon     Contra Costa      75,049
# 369                        Santa Ana           Orange     336,462
# 370                    Santa Barbara    Santa Barbara      90,889
# 371                      Santa Clara      Santa Clara     121,114
# 372                    Santa Clarita      Los Angeles     206,930
# 373                       Santa Cruz       Santa Cruz      63,440
# 374                 Santa Fe Springs      Los Angeles      17,254
# 375                      Santa Maria    Santa Barbara     102,885
# 376                     Santa Monica      Los Angeles      93,151
# 377                      Santa Paula          Ventura      30,269
# 378                       Santa Rosa           Sonoma     172,991
# 379                           Santee        San Diego      56,737
# 380                         Saratoga      Santa Clara      31,122
# 381                        Sausalito            Marin       7,137
# 382                    Scotts Valley       Santa Cruz      11,795
# 383                       Seal Beach           Orange      24,727
# 384                          Seaside         Monterey      34,350
# 385                       Sebastopol           Sonoma       7,646
# 386                            Selma           Fresno      24,404
# 387                          Shafter             Kern      17,235
# 388                     Sierra Madre      Los Angeles      11,090
# 389                      Signal Hill      Los Angeles      11,411
# 390                      Simi Valley          Ventura     126,604
# 391                     Solana Beach        San Diego      13,321
# 392                          Soledad         Monterey      25,807
# 393                          Solvang    Santa Barbara       5,418
# 394                           Sonoma           Sonoma      10,950
# 395                           Sonora         Tuolumne       4,786
# 396                   South El Monte      Los Angeles      20,465
# 397                       South Gate      Los Angeles      95,981
# 398                 South Lake Tahoe        El Dorado      21,379
# 399                   South Pasadena      Los Angeles      26,041
# 400              South San Francisco        San Mateo      66,793
# 401                 Stallion Springs             Kern       2,587
# 402                          Stanton           Orange      38,791
# 403                         Stockton      San Joaquin     299,519
# 404                      Suisun City           Solano      28,986
# 405                        Sunnyvale      Santa Clara     149,384
# 406                       Susanville           Lassen      15,048
# 407                     Sutter Creek           Amador       2,438
# 408                             Taft             Kern       8,895
# 409                        Tehachapi             Kern      12,997
# 410                         Temecula        Riverside     108,308
# 411                      Temple City      Los Angeles      36,272
# 412                    Thousand Oaks          Ventura     129,175
# 413                          Tiburon            Marin       9,232
# 414                         Torrance      Los Angeles     147,971
# 415                            Tracy      San Joaquin      85,078
# 416                          Truckee           Nevada      16,161
# 417                           Tulare           Tulare      61,596
# 418                         Tulelake         Siskiyou         988
# 419                          Turlock       Stanislaus      70,786
# 420                           Tustin           Orange      79,046
# 421                 Twentynine Palms   San Bernardino      25,936
# 422                            Ukiah        Mendocino      15,836
# 423                       Union City          Alameda      73,268
# 424                           Upland   San Bernardino      75,790
# 425                        Vacaville           Solano      94,701
# 426                          Vallejo           Solano     119,504
# 427                           Vernon      Los Angeles         115
# 428                      Victorville   San Bernardino     122,316
# 429                       Villa Park           Orange       5,982
# 430                          Visalia           Tulare     128,488
# 431                            Vista        San Diego      97,651
# 432                           Walnut      Los Angeles      30,282
# 433                     Walnut Creek     Contra Costa      67,555
# 434                        Waterford       Stanislaus       8,646
# 435                      Watsonville       Santa Cruz      52,778
# 436                             Weed         Siskiyou       2,894
# 437                      West Covina      Los Angeles     108,136
# 438                   West Hollywood      Los Angeles      35,507
# 439                 Westlake Village      Los Angeles       8,452
# 440                      Westminster           Orange      92,217
# 441                      Westmorland         Imperial       2,264
# 442                  West Sacramento             Yolo      50,152
# 443                        Wheatland             Yuba       3,521
# 444                         Whittier      Los Angeles      86,952
# 445                         Wildomar        Riverside      33,921
# 446                         Williams           Colusa       5,188
# 447                          Willits        Mendocino       4,814
# 448                          Willows            Glenn       6,089
# 449                          Windsor           Sonoma      27,350
# 450                          Winters             Yolo       6,962
# 451                         Woodlake           Tulare       7,700
# 452                         Woodland             Yolo      56,854
# 453                      Yorba Linda           Orange      67,702
# 454                       Yountville             Napa       2,978
# 455                            Yreka         Siskiyou       7,558
# 456                        Yuba City           Sutter      65,525
# 457                          Yucaipa   San Bernardino      52,794
# 458                     Yucca Valley   San Bernardino      21,228
#
#     Population density Violent crimes  Violent crime rate per 1,000 persons  \
# 0                557.3             189                                 6.06
# 1              2,664.8              17                                 0.82
# 2              7,378.7             145                                 1.88
# 3             10,822.1              31                                  1.6
# 4             11,129.7             168                                 1.98
# 5              7,323.5              35                                 0.69
# 6              1,073.9              29                                11.09
# 7              3,351.3              55                                  2.7
# 8              6,942.3           1,101                                 3.17
# 9              1,597.0              96                                 9.43
# 10             1,024.3               7                                 1.88
# 11             3,820.1             849                                 7.84
# 12               958.2             212                                 2.97
# 13             5,304.3              60                                 1.04
# 14             1,952.0              78                                 4.39
# 15             3,056.6              52                                 2.92
# 16            10,356.6              49                                 2.92
# 17             4,262.5             177                                 8.62
# 18             1,138.3              72                                 2.46
# 19             1,435.9               3                                 0.42
# 20             4,736.8             182                                 6.28
# 21             1,962.8              44                                 3.13
# 22             1,289.3              20                                 5.29
# 23               716.4              18                                 1.29
# 24             4,994.2             165                                 3.42
# 25             2,473.3           1,678                                 4.57
# 26            11,602.0             219                                 2.85
# 27             1,329.0             128                                 4.17
# 28               564.8             217                                 9.29
# 29             1,334.4              71                                 1.72
# 30            14,417.8             217                                 6.02
# 31            12,721.5             293                                 3.76
# 32            17,523.0             108                                 2.51
# 33             5,826.4              36                                 1.34
# 34             4,113.7               1                                 0.47
# 35             2,147.6              26                                 0.94
# 36            11,251.0             431                                 3.66
# 37             6,094.6             111                                 3.19
# 38               811.1              44                                 8.55
# 39             2,674.5              17                                 9.99
# 40             2,070.8              27                                 6.99
# 41               751.0              88                                 4.47
# 42               553.9               2                                 1.85
# 43             3,344.8              69                                 2.69
# 44             3,392.0              53                                 1.28
# 45             3,759.1             102                                 1.83
# 46             1,447.7              11                                 2.45
# 47             9,629.7              10                                  2.3
# 48             3,158.7               6                                  1.2
# 49             7,926.1             217                                  2.6
# 50             6,057.4             150                                 1.43
# 51             6,847.0              47                                 1.56
# 52             1,774.8              19                                 0.78
# 53             4,584.3              96                                 2.43
# 54                64.7              79                                  6.0
# 55               554.9              17                                 2.06
# 56             2,031.2               3                                 0.57
# 57             3,393.0              72                                 1.09
# 58             7,042.0              81                                 1.98
# 59             2,809.3              13                                 1.18
# 60             6,361.6              30                                 2.96
# 61             2,976.6             204                                 1.82
# 62             3,584.3              13                                 3.36
# 63             5,280.0              19                                 1.39
# 64             4,958.5             339                                 3.65
# 65             2,482.2             128                                  2.4
# 66             5,028.2             145                                 3.09
# 67             5,717.4              86                                 1.72
# 68             2,690.1             340                                 3.84
# 69             2,750.8             186                                 2.28
# 70             1,722.5              61                                 0.79
# 71             1,533.5              89                                 5.21
# 72             5,236.5             612                                 2.35
# 73             6,027.0             389                                 4.54
# 74             2,699.8              39                                 1.08
# 75             3,032.8               4                                 0.34
# 76             1,472.4              97                                  6.5
# 77             2,887.4              15                                 1.71
# 78             4,291.3             216                                 2.14
# 79             1,507.2             166                                  3.8
# 80             2,463.3             121                                 7.36
# 81               789.0              12                                 7.98
# 82             3,490.3             137                                 2.56
# 83             3,239.9               9                                 1.51
# 84             1,993.4              77                                 5.91
# 85             9,810.6           1,129                                11.49
# 86             4,149.6             465                                 3.67
# 87             3,072.6              86                                 3.73
# 88             2,132.1              35                                 4.62
# 89             4,148.9             171                                 1.06
# 90             2,948.6              17                                 0.73
# 91             7,178.9             318                                 2.82
# 92             3,948.9              33                                 4.45
# 93             6,926.7             110                                 2.26
# 94             3,611.8              63                                 8.89
# 95            20,574.5              81                                 3.35
# 96             7,740.4             169                                 4.27
# 97             5,354.4              40                                 0.66
# 98             7,467.9              51                                 1.03
# 99            13,825.7             194                                 1.84
# 100            5,269.1              71                                 2.07
# 101            2,416.6              17                                 0.39
# 102            6,714.6              84                                 1.27
# 103            3,651.3             215                                 4.12
# 104            2,522.0              18                                 4.18
# 105            3,506.2               1                                 0.59
# 106              930.0             168                                 5.98
# 107            3,808.4              49                                 0.86
# 108            3,680.8             187                                 7.85
# 109            2,680.0              53                                 2.77
# 110            1,280.6               5                                 5.56
# 111            3,766.5              51                                10.04
# 112            9,155.0             281                                 2.47
# 113            3,261.1              54                                 2.48
# 114            3,531.5              70                                  1.3
# 115              978.2               5                                 3.19
# 116           11,722.7             124                                 4.22
# 117            4,383.2              59                                 1.06
# 118            7,103.1             327                                 3.18
# 119            3,927.5             167                                 3.84
# 120            6,695.4              77                                 3.14
# 121            3,862.2             622                                 3.82
# 122           12,154.4             333                                 2.87
# 123            1,625.2             125                                 4.02
# 124            3,110.0              48                                 2.83
# 125            8,565.2             117                                10.66
# 126            3,299.5             104                                 1.68
# 127            3,164.3              10                                 1.37
# 128            4,043.3             512                                 3.42
# 129              940.8               0                                  0.0
# 130            2,860.5             145                                  5.4
# 131            4,272.8              47                                 4.47
# 132            3,469.6              16                                 2.09
# 133            2,950.1             519                                 4.71
# 134            4,761.7              52                                 4.84
# 135            1,324.2               3                                 2.21
# 136            4,551.4              46                                  3.0
# 137            2,343.7              75                                  9.1
# 138            3,341.2              79                                 1.08
# 139            4,820.5             710                                 3.47
# 140            2,635.5              27                                 3.73
# 141            1,131.2               0                                  0.0
# 142            2,425.6              33                                 2.81
# 143            8,650.2              14                                 0.43
# 144            6,285.7              86                                 1.51
# 145            2,372.9              49                                 8.12
# 146            2,937.8             284                                 1.25
# 147            4,532.5           2,382                                 4.64
# 148            6,236.1             339                                 2.42
# 149            4,115.3              70                                 2.84
# 150           10,333.3             276                                 4.58
# 151            9,807.1             406                                 2.31
# 152            3,247.1             197                                 3.76
# 153            6,473.5             186                                 0.94
# 154            2,644.1              66                                 1.29
# 155            3,906.4              35                                 1.14
# 156            4,412.6              37                                 4.37
# 157            3,542.3              18                                 1.45
# 158            2,693.9             109                                 8.53
# 159            7,956.0              91                                 5.36
# 160            3,168.1              88                                13.42
# 161            5,842.9              52                                 3.85
# 162            5,546.2              10                                 1.38
# 163            3,653.8              34                                  6.0
# 164            3,262.6             305                                 5.56
# 165           15,284.8              55                                  3.8
# 166           14,252.6             658                                 7.59
# 167            3,375.6             605                                 3.95
# 168            2,595.7              19                                 1.64
# 169            2,959.5             430                                 5.22
# 170            3,903.0              27                                 1.08
# 171           13,926.4              37                                 1.86
# 172            1,266.7             296                                  3.2
# 173            1,133.8               0                                  0.0
# 174            2,909.0             256                                 4.69
# 175            1,838.8               1                                 0.09
# 176            5,047.4             136                                 3.68
# 177            5,252.6              24                                 3.98
# 178            3,587.6              11                                 1.55
# 179            7,394.1             391                                 1.96
# 180           19,603.1             409                                 6.92
# 181            4,269.0              72                                 10.6
# 182            2,823.6               5                                  0.3
# 183            6,545.1             112                                 4.11
# 184              363.8               6                                 1.15
# 185            2,757.6             466                                 5.51
# 186               17.4              72                               351.22
# 187           12,350.8             783                                 6.99
# 188            1,474.0               6                                 0.89
# 189            3,705.5             120                                 0.49
# 190              161.6              18                                12.62
# 191            1,875.0               2                                 2.42
# 192            1,215.5              17                                 3.75
# 193            2,298.7             287                                 2.91
# 194            5,576.6               2                                 0.38
# 195            4,496.8              38                                 2.61
# 196            3,468.4              55                                 4.12
# 197            4,165.0              34                                 2.89
# 198            2,390.7              18                                 0.87
# 199            1,685.1              17                                 0.67
# 200            2,627.7              64                                 2.74
# 201            4,701.6              45                                 1.45
# 202            4,411.7              73                                 1.12
# 203            4,926.8               6                                 0.36
# ...
# 197              318                                 27.04
# 198              306                                 14.83
# 199              439                                 17.31
# 200              462                                 19.77
# 201              441                                 14.21
# 202              554                                  8.52
# 203              118                                  7.16
# 204            1,049                                 16.93
# 205               49                                  8.99
# 206            1,662                                 28.33
# 207              682                                  8.55
# 208              335                                 70.33
# 209            1,737                                 21.34
# 210            1,584                                 26.85
# 211              635                                 12.89
# 212            3,661                                 22.85
# 213              247                                 15.46
# 214              440                                 10.84
# 215            1,324                                 33.31
# 216              820                                 25.57
# 217              398                                 11.94
# 218              516                                  19.6
# 219              660                                 26.32
# 220              463                                 10.11
# 221              243                                 18.27
# 222            1,501                                 17.42
# 223              245                                  17.9
# 224            2,095                                 32.94
# 225              689                                 28.95
# 226              355                                 17.17
# 227              854                                 19.49
# 228           12,438                                  26.4
# 229              204                                 17.42
# 230              322                                 10.64
# 231               73                                  8.68
# 232           83,139                                 21.28
# 233              900                                 24.32
# 234              616                                 20.12
# 235            1,424                                 19.83
# 236              230                                 18.63
# 237            1,686                                 26.55
# 238              312                                 24.16
# 239              111                                 13.82
# 240              878                                 24.48
# 241            2,100                                 28.75
# 242              463                                 22.55
# 243              974                                 26.03
# 244              507                                 41.41
# 245              250                                  8.98
# 246              287                                  25.0
# 247            1,501                                 17.69
# 248              565                                 16.96
# 249            2,632                                 32.25
# 250              188                                 13.05
# 251            2,131                                  30.2
# 252              864                                   8.9
# 253            9,113                                 44.28
# 254              718                                 19.29
# 255               13                                   9.3
# 256            1,506                                 39.27
# 257            1,449                                 22.73
# 258            1,022                                 35.84
# 259            1,039                                 16.95
# 260               30                                  8.54
# 261              277                                  7.85
# 262              150                                  8.85
# 263            6,410                                 31.59
# 264              612                                 14.72
# 265              234                                 22.25
# 266            1,608                                 20.42
# 267               62                                 18.98
# 268            1,458                                 13.45
# 269            1,315                                 16.53
# 270            1,589                                 26.43
# 271              164                                 33.17
# 272               95                                  31.1
# 273              971                                 21.84
# 274              157                                 14.62
# 275            1,880                                 21.42
# 276              642                                 23.84
# 277            2,001                                 18.73
# 278              770                                 14.06
# 279              822                                 37.97
# 280           24,367                                 59.43
# 281              469                                 12.07
# 282            3,984                                 22.88
# 283              120                                 15.77
# 284            4,654                                 27.66
# 285            2,241                                 15.92
# 286              151                                 15.56
# 287              187                                  9.89
# 288              123                                 16.38
# 289              994                                 61.78
# 290            6,382                                 31.26
# 291              638                                 16.39
# 292              301                                 19.28
# 293            3,219                                 20.35
# 294            2,178                                 42.73
# 295            2,722                                 58.33
# 296            1,299                                 19.34
# 297              121                                  8.85
# 298              516                                 19.62
# 299            1,408                                 25.51
# 300              234                                 15.65
# 301            3,469                                 24.71
# 302              626                                 29.84
# 303            1,905                                 26.02
# 304            1,074                                 17.96
# 305            1,360                                 21.26
# 306              232                                 20.77
# 307              632                                  33.2
# 308              387                                 48.93
# 309            2,362                                 34.99
# 310              732                                 13.94
# 311              273                                 26.03
# 312            1,738                                 50.58
# 313            1,244                                 16.57
# 314            4,403                                 28.99
# 315            1,204                                 21.74
# 316              347                                  15.6
# 317              436                                  8.76
# 318            1,644                                 23.95
# 319            3,668                                 21.24
# 320              677                                 37.77
# 321              472                                 11.07
# 322              203                                   4.1
# 323              911                                  64.6
# 324            3,924                                 42.92
# 325            2,837                                 40.36
# 326            1,447                                 21.26
# 327            1,728                                 21.11
# 328              460                                 18.26
# 329            2,154                                 21.01
# 330            4,281                                 39.47
# 331              470                                  16.3
# 332               57                                 16.97
# 333              116                                 14.82
# 334              258                                 17.36
# 335              688                                 29.04
# 336            9,864                                 30.88
# 337            1,039                                 17.21
# 338              735                                  17.7
# 339               18                                  9.49
# 340              114                                 13.85
# 341            1,186                                 21.66
# 342            3,070                                  23.8
# 343               21                                  8.48
# 344           15,078                                 31.23
# 345               56                                  9.37
# 346            5,227                                 33.31
# 347            9,239                                 43.05
# 348            1,054                                 24.63
# 349            3,867                                  35.4
# 350              687                                 10.51
# 351              165                                481.05
# 352           26,812                                 19.59
# 353              631                                 18.58
# 354              406                                 16.67
# 355           45,093                                 53.03
# 356              555                                 13.73
# 357              549                                 22.16
# 358            1,875                                 40.57
# 359           24,577                                 24.34
# 360              383                                  10.6
# 361            3,757                                 42.36
# 362            1,439                                 30.83
# 363            1,286                                 14.16
# 364              221                                 16.53
# 365            1,944                                 19.04
# 366            1,162                                 38.95
# 367            1,664                                 28.06
# 368              748                                  9.97
# 369            5,784                                 17.19
# 370            2,389                                 26.28
# 371            3,268                                 26.98
# 372            2,437                                 11.78
# 373            3,270                                 51.54
# 374            1,124                                 65.14
# 375            3,045                                  29.6
# 376            3,026                                 32.48
# 377              447                                 14.77
# 378            3,850                                 22.26
# 379              794                                 13.99
# 380              288                                  9.25
# 381              232                                 32.51
# 382              264                                 22.38
# 383              494                                 19.98
# 384              507                                 14.76
# 385              124                                 16.22
# 386              986                                  40.4
# 387              462                                 26.81
# 388               92                                   8.3
# 389              500                                 43.82
# 390            1,618                                 12.78
# 391              188                                 14.11
# 392              232                                  8.99
# 393               81                                 14.95
# 394              166                                 15.16
# 395              335                                  70.0
# 396              647                                 31.61
# 397            2,687                                  28.0
# 398              516                                 24.14
# 399              475                                 18.24
# 400            1,274                                 19.07
# 401               11                                  4.25
# 402              684                                 17.63
# 403           13,148                                  43.9
# 404              606                                 20.91
# 405            2,356                                 15.77
# 406              315                                 20.93
# 407               42                                 17.23
# 408              276                                 31.03
# 409              309                                 23.77
# 410            2,535                                 23.41
# 411              428                                  11.8
# 412            1,599                                 12.38
# 413              107                                 11.59
# 414            2,623                                 17.73
# 415            2,262                                 26.59
# 416              164                                 10.15
# 417            2,054                                 33.35
# 418                3                                  3.04
# 419            2,510                                 35.46
# 420            1,356                                 17.15
# 421              301                                 11.61
# 422              551                                 34.79
# 423            1,602                                 21.86
# 424            2,165                                 28.57
# 425            2,587                                 27.32
# 426            4,877                                 40.81
# 427              312                              2,713.04
# 428            4,374                                 35.76
# 429               84                                 14.04
# 430            3,796                                 29.54
# 431            1,686                                 17.27
# 432              294                                  9.71
# 433            2,439                                  36.1
# 434              196                                 22.67
# 435            1,489                                 28.21
# 436               84                                 29.03
# 437            2,832                                 26.19
# 438            1,325                                 37.32
# 439              173                                 20.47
# 440            2,210                                 23.97
# 441                4                                  1.77
# 442            1,295                                 25.82
# 443               50                                  14.2
# 444            2,247                                 25.84
# 445              550                                 16.21
# 446               64                                 12.34
# 447               50                                 10.39
# 448              167                                 27.43
# 449              254                                  9.29
# 450              155                                 22.26
# 451              122                                 15.84
# 452            1,756                                 30.89
# 453              702                                 10.37
# 454               40                                 13.43
# 455              298                                 39.43
# 456            1,699                                 25.93
# 457              978                                 18.52
# 458              533                                 25.11

# %% [markdown]
# We inner join the two data sets with the job opening data by city and the crime rate data. We come up with the dataframe below which contains all cities in the Bay Area with job openings, and violent and property crime rates for these cities.

# %%
df_crime.rename(columns={'City/Agency ':'City'},inplace=True)


df_crime_rate= df_crime[['City','Violent crime rate per 1,000 persons','Property crime rate per 1,000 persons']]

df1 = df.merge(df_crime_rate, how='inner', on='City')

df1[['Violent crime rate per 1,000 persons','Property crime rate per 1,000 persons']]=df1[['Violent crime rate per 1,000 persons','Property crime rate per 1,000 persons']].apply(pd.to_numeric)

df1
# Out:
#                    City  Job Openings  Violent crime rate per 1,000 persons  \
# 0         San Francisco          1439                                  7.95
# 1             Sunnyvale           529                                  1.12
# 2              San Jose           258                                  3.21
# 3             Palo Alto           247                                  0.88
# 4            Menlo Park           241                                  1.56
# 5   South San Francisco           240                                  2.34
# 6           Santa Clara           201                                  1.34
# 7         Mountain View           200                                  1.98
# 8          Redwood City           186                                  2.37
# 9             Livermore           115                                  2.74
# 10             Berkeley            77                                  3.66
# 11            San Mateo            75                                  2.25
# 12              Oakland            69                                 16.85
#
#     Property crime rate per 1,000 persons
# 0                                   53.03
# 1                                   15.77
# 2                                   24.34
# 3                                   19.34
# 4                                   16.96
# 5                                   19.07
# 6                                   26.98
# 7                                   20.42
# 8                                   21.11
# 9                                   17.42
# 10                                  43.33
# 11                                  19.04
# 12                                  59.43

# %% [markdown]
# ### 2.3. Venue and rating data for each city:
#
# We can use the Foursquare API data to extract the nearby Turkish restaurants for each city and their ratings.

# %%
CLIENT_ID = 'KJ1V24Q1GYPAUPGCPKTQ130M0UXG21Q0S1W2SI2AGPHUP4WB' # my Foursquare ID
CLIENT_SECRET = 'IJLZNOPFSPLXD41DUOA4YIDZXCD3ZSAKMK4SXJTISANLZTS2' # my Foursquare Secret
VERSION = '20190321' # Foursquare API version

print('Credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Credentails:
# CLIENT_ID: KJ1V24Q1GYPAUPGCPKTQ130M0UXG21Q0S1W2SI2AGPHUP4WB
# CLIENT_SECRET:IJLZNOPFSPLXD41DUOA4YIDZXCD3ZSAKMK4SXJTISANLZTS2

# %% [markdown]
# #### Turkish Restaurants in San Francisco
#
# We will first show in detail how we come up with the average rating of Turkish restaurants in San Francisco by using the Foursquare API. Then, we will apply the same logic to extract the average rating of Turkish restaurants in all cities listed in the final dataframe above.
#
# We first search up to 20 Turkish restaurants near San Francisco, CA by using the category ID for "Turkish Restaurant" in [Foursquare venue categories list](https://developer.foursquare.com/docs/resources/categories). We set the limit as 20 because it is a premium request to get the details of a venue in Forsquare API, which includes the rating data. We have 13 cities with possibly 20 Turkish restaurants each. Given that we can only send 500 premium requests per day, the limit of 20 restaurants for each city seems to be a reasonable number considering the requests sent during debugging.

# %%
LIMIT=20
city='San Francisco, CA'
Turkish='4f04af1f2fb6e1c99f3db0bb'
# type your answer here
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&near={}&categoryId={}&v={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, city, Turkish,VERSION, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=KJ1V24Q1GYPAUPGCPKTQ130M0UXG21Q0S1W2SI2AGPHUP4WB&client_secret=IJLZNOPFSPLXD41DUOA4YIDZXCD3ZSAKMK4SXJTISANLZTS2&near=San Francisco, CA&categoryId=4f04af1f2fb6e1c99f3db0bb&v=20190321&limit=20'

# %% [markdown]
# We send the get request for the above url and examine the data.

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c98049cdd579725dd239dcd'},
#  'response': {'venues': [{'id': '4a6cc33df964a52091d11fe3',
#     'name': 'A La Turca Restaurant',
#     'location': {'address': '869 Geary St',
#      'crossStreet': 'Larkin St.',
#      'lat': 37.78614159981687,
#      'lng': -122.41758355741563,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78614159981687,
#        'lng': -122.41758355741563}],
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['869 Geary St (Larkin St.)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '305120',
#      'url': 'https://www.grubhub.com/restaurant/a-la-turca-869-geary-st-san-francisco/305120?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=305120',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '117422769'},
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '49fb9750f964a5205f6e1fe3',
#     'name': "Eden's Mediterranean Turkish & Greek Restaurant",
#     'location': {'address': '552 Jones St',
#      'crossStreet': 'at Geary St',
#      'lat': 37.78661222741304,
#      'lng': -122.41315928739509,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78661222741304,
#        'lng': -122.41315928739509}],
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['552 Jones St (at Geary St)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '5a1baf41628c837b43898792',
#     'name': 'Doner Kebab',
#     'location': {'lat': 37.867903,
#      'lng': -122.257704,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.867903,
#        'lng': -122.257704}],
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Berkeley, CA 94704', 'United States']},
#     'categories': [{'id': '5283c7b4e4b094cb91ec88d8',
#       'name': 'Doner Restaurant',
#       'pluralName': 'Doner Restaurants',
#       'shortName': 'Doner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '786155',
#      'url': 'https://www.grubhub.com/restaurant/doner-and-kebab-2528a-durant-ave-berkeley/786155?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=786155',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '59dfd5e0419a9e7fcc3637e1',
#     'name': 'Yaprak Doner',
#     'location': {'address': '1199 Broadway',
#      'lat': 37.586193,
#      'lng': -122.364494,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.586193,
#        'lng': -122.364494}],
#      'postalCode': '94010',
#      'cc': 'US',
#      'city': 'Burlingame',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1199 Broadway',
#       'Burlingame, CA 94010',
#       'United States']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '54f8caef498e72f9a012bd6a',
#     'name': 'Cobani Gyro & Kebab',
#     'location': {'address': '8 W 25th Ave',
#      'lat': 37.54423684459634,
#      'lng': -122.30602733486171,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.54423684459634,
#        'lng': -122.30602733486171}],
#      'postalCode': '94403',
#      'cc': 'US',
#      'city': 'San Mateo',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['8 W 25th Ave',
#       'San Mateo, CA 94403',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '337533',
#      'url': 'https://www.grubhub.com/restaurant/cobani-gyro-kebab-8-w-25th-ave-san-mateo/337533?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=337533',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '51589757e4b0d20cd97f70ac',
#     'name': 'Hummus Mediterranean Kitchen',
#     'location': {'address': '150 E 4th Ave',
#      'crossStreet': 'btwn San Mateo & Ellsworth',
#      'lat': 37.56381280511829,
#      'lng': -122.32265399269157,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.56381280511829,
#        'lng': -122.32265399269157}],
#      'postalCode': '94401',
#      'cc': 'US',
#      'city': 'San Mateo',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['150 E 4th Ave (btwn San Mateo & Ellsworth)',
#       'San Mateo, CA 94401',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '280642',
#      'url': 'https://www.grubhub.com/restaurant/hummus-mediterranean-kitchen-150-e-4th-ave-san-mateo/280642?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=280642',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '4a6dfb5df964a52082d31fe3',
#     'name': 'Turkish Kitchen',
#     'location': {'address': '1986 Shattuck Ave',
#      'crossStreet': 'at University Avenue',
#      'lat': 37.87248195041857,
#      'lng': -122.26845704782052,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.87248195041857,
#        'lng': -122.26845704782052}],
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1986 Shattuck Ave (at University Avenue)',
#       'Berkeley, CA 94704',
#       'United States']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '421666',
#      'url': 'https://www.grubhub.com/restaurant/turkish-kitchen-1986-shattuck-ave-berkeley/421666?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=421666',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '501602a7e4b053557197cb9a',
#     'name': 'Arkadaslarin yeri',
#     'location': {'lat': 37.52477808829957,
#      'lng': -122.29266583814852,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.52477808829957,
#        'lng': -122.29266583814852}],
#      'postalCode': '94002',
#      'cc': 'US',
#      'city': 'Belmont',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Belmont, CA 94002', 'United States']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '51620309e4b09f3a6d85ac0b',
#     'name': 'Aspendos',
#     'location': {'address': '514 Peninsula Ave',
#      'lat': 37.5799674987793,
#      'lng': -122.33480072021484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.5799674987793,
#        'lng': -122.33480072021484}],
#      'postalCode': '94401',
#      'cc': 'US',
#      'city': 'San Mateo',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['514 Peninsula Ave',
#       'San Mateo, CA 94401',
#       'United States']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '4ff74283e4b045d12e3465dd',
#     'name': 'Turkish Kitchen Express',
#     'location': {'address': '2395 Telegraph Ave',
#      'crossStreet': 'Channing Way',
#      'lat': 37.867151,
#      'lng': -122.258719,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.867151,
#        'lng': -122.258719}],
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2395 Telegraph Ave (Channing Way)',
#       'Berkeley, CA 94704',
#       'United States']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '4f9b6d4fe4b06144923e972a',
#     'name': 'Troya',
#     'location': {'address': '2125 Fillmore St',
#      'crossStreet': 'btwn California & Sacramento St',
#      'lat': 37.78936899131718,
#      'lng': -122.43396340531939,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78936899131718,
#        'lng': -122.43396340531939}],
#      'postalCode': '94115',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2125 Fillmore St (btwn California & Sacramento St)',
#       'San Francisco, CA 94115',
#       'United States']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '91164224'},
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '49ed2342f964a520cb671fe3',
#     'name': 'Kitchen Istanbul',
#     'location': {'address': '349 Clement St',
#      'crossStreet': 'at 5th Ave',
#      'lat': 37.78294319653059,
#      'lng': -122.46330393358751,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78294319653059,
#        'lng': -122.46330393358751}],
#      'postalCode': '94118',
#      'cc': 'US',
#      'neighborhood': 'Inner Richmond',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['349 Clement St (at 5th Ave)',
#       'San Francisco, CA 94118',
#       'United States']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '104260380'},
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '59d7d65b0c9f316842f19329',
#     'name': 'SINI',
#     'location': {'address': '322 Kearny St',
#      'lat': 37.7912691000328,
#      'lng': -122.40394535389682,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.7912691000328,
#        'lng': -122.40394535389682}],
#      'postalCode': '94108',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['322 Kearny St',
#       'San Francisco, CA 94108',
#       'United States']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '699935',
#      'url': 'https://www.grubhub.com/restaurant/the-sini-322-kearny-st-san-francisco/699935?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=699935',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '51cf5189498eddc6c9cc6e9e',
#     'name': "Cheko's Cafe",
#     'location': {'address': '1300 Bayshore Hwy',
#      'lat': 37.59332480252072,
#      'lng': -122.36309811863302,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.59332480252072,
#        'lng': -122.36309811863302}],
#      'postalCode': '94010',
#      'cc': 'US',
#      'city': 'Burlingame',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1300 Bayshore Hwy',
#       'Burlingame, CA 94010',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1553466524',
#     'hasPerk': False},
#    {'id': '4b4407a2f964a52074f025e3',
#     'name': 'Tuba - Authentic Turkish Restaurant',
#     'location': {'address': '1007 Guerrero St',
#      'crossStreet': 'at 22nd St',
#      'lat': 37.75496349644156,
#      'lng': -122.42313816692466,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.75496349644156,
#        'lng': -122.42313816692466}],
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1007 Guerrero St (at 22nd St)',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '281975',
#      'url': 'https://www.grubhub.com/restaurant/tuba-restaurant-1007-guerrero-st-san-francisco/281975?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=281975',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '78708839'},
#     'referralId': 'v-1553466524',
#     'hasPerk': False}],
#   'confident': False,
#   'geocode': {'what': '',
#    'where': 'san francisco ca',
#    'feature': {'cc': 'US',
#     'name': 'San Francisco',
#     'displayName': 'San Francisco, CA, United States',
#     'matchedName': 'San Francisco, CA, United States',
#     'highlightedName': '<b>San Francisco</b>, <b>CA</b>, United States',
#     'woeType': 7,
#     'slug': 'san-francisco-california',
#     'id': 'geonameid:5391959',
#     'longId': '72057594043319895',
#     'geometry': {'center': {'lat': 37.77493, 'lng': -122.41942},
#      'bounds': {'ne': {'lat': 37.833687, 'lng': -122.34905},
#       'sw': {'lat': 37.708085, 'lng': -122.536232}}}},
#    'parents': []}}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venues.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# We pull the id, name and category of each venue from the results and put the data into the dataframe below:

# %%
venues = results['response']['venues']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['id','name','categories']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['categories'] = nearby_venues.apply(get_category_type, axis=1)

nearby_venues
# Out:
#                           id                                             name  \
# 0   4a6cc33df964a52091d11fe3                            A La Turca Restaurant
# 1   49fb9750f964a5205f6e1fe3  Eden's Mediterranean Turkish & Greek Restaurant
# 2   5a1baf41628c837b43898792                                      Doner Kebab
# 3   59dfd5e0419a9e7fcc3637e1                                     Yaprak Doner
# 4   54f8caef498e72f9a012bd6a                              Cobani Gyro & Kebab
# 5   51589757e4b0d20cd97f70ac                     Hummus Mediterranean Kitchen
# 6   4a6dfb5df964a52082d31fe3                                  Turkish Kitchen
# 7   501602a7e4b053557197cb9a                                Arkadaslarin yeri
# 8   51620309e4b09f3a6d85ac0b                                         Aspendos
# 9   4ff74283e4b045d12e3465dd                          Turkish Kitchen Express
# 10  4f9b6d4fe4b06144923e972a                                            Troya
# 11  49ed2342f964a520cb671fe3                                 Kitchen Istanbul
# 12  59d7d65b0c9f316842f19329                                             SINI
# 13  51cf5189498eddc6c9cc6e9e                                     Cheko's Cafe
# 14  4b4407a2f964a52074f025e3              Tuba - Authentic Turkish Restaurant
#
#                   categories
# 0         Turkish Restaurant
# 1   Mediterranean Restaurant
# 2           Doner Restaurant
# 3         Turkish Restaurant
# 4   Mediterranean Restaurant
# 5   Mediterranean Restaurant
# 6         Turkish Restaurant
# 7         Turkish Restaurant
# 8         Turkish Restaurant
# 9         Turkish Restaurant
# 10        Turkish Restaurant
# 11        Turkish Restaurant
# 12        Turkish Restaurant
# 13  Mediterranean Restaurant
# 14        Turkish Restaurant

# %% [markdown]
# We then use the id of each venue above to get the details of each venue through Foursquare API. From these details, we extract the name and rating of each venue:

# %%
venue_ratings=pd.DataFrame(columns=['name','rating'])
for i in range(nearby_venues.shape[0]):
    
    VENUE_ID=nearby_venues.loc[i,'id']
    url1 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(VENUE_ID, CLIENT_ID, CLIENT_SECRET, VERSION)
    results1 = requests.get(url1).json()
    venue = results1['response']['venue']
    venue_details= json_normalize(venue) # flatten JSON
    filtered_columns = ['name','rating']
    venue_ratings = venue_ratings.append(venue_details.loc[:, filtered_columns])

venue_ratings
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                               name  rating
# 0                            A La Turca Restaurant     8.0
# 0  Eden's Mediterranean Turkish & Greek Restaurant     NaN
# 0                                      Doner Kebab     NaN
# 0                                     Yaprak Doner     NaN
# 0                              Cobani Gyro & Kebab     8.5
# 0                     Hummus Mediterranean Kitchen     7.6
# 0                                  Turkish Kitchen     7.3
# 0                                Arkadaslarin yeri     NaN
# 0                                         Aspendos     NaN
# 0                          Turkish Kitchen Express     NaN
# 0                                            Troya     7.6
# 0                                 Kitchen Istanbul     8.2
# 0                                             SINI     6.2
# 0                                     Cheko's Cafe     7.9
# 0              Tuba - Authentic Turkish Restaurant     8.7

# %% [markdown]
# We drop the venues which are not rated and reset the index of the dataframe.

# %%
venue_ratings.dropna(inplace=True)
venue_ratings.reset_index(drop=True, inplace=True)
venue_ratings
# Out:
#                                   name  rating
# 0                A La Turca Restaurant     8.0
# 1                  Cobani Gyro & Kebab     8.5
# 2         Hummus Mediterranean Kitchen     7.6
# 3                      Turkish Kitchen     7.3
# 4                                Troya     7.6
# 5                     Kitchen Istanbul     8.2
# 6                                 SINI     6.2
# 7                         Cheko's Cafe     7.9
# 8  Tuba - Authentic Turkish Restaurant     8.7

# %% [markdown]
# We finally calculate the average rating of the restaurants above:

# %%
venue_ratings.rating.mean()
# Out:
# 7.777777777777778

# %% [markdown]
# #### The average rating of Turkish restaurants in 13 cities:
#
# We will now repeat the same procedure above to get the average rating of nearby restaurants in all cities specified in subsection 2.2.

# %%
#Loop through each city specified in the final dataframe in subsection 2.2
for j in range(df1.shape[0]):

    # Extract the restaurants in each city
    LIMIT=20
    city=df1.loc[j,'City']+', CA'
    query='Restaurant'
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&near={}&query={}&v={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, city, query,VERSION, LIMIT)
    results = requests.get(url).json()
    venues = results['response']['venues']
    
    nearby_venues = json_normalize(venues) # flatten JSON

    # filter columns
    filtered_columns = ['id','name','categories']
    nearby_venues =nearby_venues.loc[:, filtered_columns]

    venue_ratings1=pd.DataFrame(columns=['name','rating'])

    #Loop through each venue to pull the rating of each venue from the venue details
    for i in range(nearby_venues.shape[0]):
    
        VENUE_ID=nearby_venues.loc[i,'id']
        url1 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(VENUE_ID, CLIENT_ID, CLIENT_SECRET, VERSION)
        results1 = requests.get(url1).json()
        venue1 = results1['response']['venue']
        venue_details= json_normalize(venue1) # flatten JSON
        filtered_columns = ['name','rating']
        venue_ratings1 = venue_ratings1.append(venue_details.loc[:, filtered_columns])
        venue_ratings1.dropna(inplace=True)
        venue_ratings1.reset_index(drop=True)
    
    #Put the average rating of Turkish restaurants in each city into the 'Average Restaurant Ratings' column of the dataframe in subsection 2.2
    df1.loc[j,'Average Restaurant Ratings']=venue_ratings1.rating.mean()

df1
# Out:
#                    City  Job Openings  Violent crime rate per 1,000 persons  \
# 0         San Francisco          1439                                  7.95
# 1             Sunnyvale           529                                  1.12
# 2              San Jose           258                                  3.21
# 3             Palo Alto           247                                  0.88
# 4            Menlo Park           241                                  1.56
# 5   South San Francisco           240                                  2.34
# 6           Santa Clara           201                                  1.34
# 7         Mountain View           200                                  1.98
# 8          Redwood City           186                                  2.37
# 9             Livermore           115                                  2.74
# 10             Berkeley            77                                  3.66
# 11            San Mateo            75                                  2.25
# 12              Oakland            69                                 16.85
#
#     Property crime rate per 1,000 persons  Average Restaurant Ratings
# 0                                   53.03                    7.800000
# 1                                   15.77                    6.890000
# 2                                   24.34                    7.092857
# 3                                   19.34                    7.294737
# 4                                   16.96                    7.321053
# 5                                   19.07                    7.247059
# 6                                   26.98                    6.968421
# 7                                   20.42                    7.200000
# 8                                   21.11                    7.194737
# 9                                   17.42                    7.123529
# 10                                  43.33                    7.526316
# 11                                  19.04                    7.225000
# 12                                  59.43                    7.941176

# %% [markdown]
# We will normalize the features above and calculate a "livability score" (a linear combination of the normalized values of all features above) for each city according to the criteria specified in the problem description and come up with a ranking of the cities according to their livability scores.
